# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
import warnings
warnings.filterwarnings("ignore")
print('Libraries loaded ✓')
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Sachini\anaconda3\Lib\asyncio\windows_events.py", line 322, in run_forever
#     super().run_forever()
#   File "C:\Users\Sachini\anaconda3\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "C:\Users\Sachini\anaconda3\Lib\asyncio\base_events.py", line 1986, in _run_once
#     handle._run()
#   File "C:\Users\Sachini\anaconda3\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Sachini\AppData\Local\Temp\ipykernel_14996\677827319.py", line 2, in <module>
#     import pandas as pd
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pandas\__init__.py", line 39, in <module>
#     from pandas.compat import (
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pandas\compat\__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pandas\compat\pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pyarrow\__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\numpy\core\_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Sachini\anaconda3\Lib\asyncio\windows_events.py", line 322, in run_forever
#     super().run_forever()
#   File "C:\Users\Sachini\anaconda3\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "C:\Users\Sachini\anaconda3\Lib\asyncio\base_events.py", line 1986, in _run_once
#     handle._run()
#   File "C:\Users\Sachini\anaconda3\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Sachini\AppData\Local\Temp\ipykernel_14996\677827319.py", line 2, in <module>
#     import pandas as pd
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pandas\__init__.py", line 62, in <module>
#     from pandas.core.api import (
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pandas\core\api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pandas\core\dtypes\dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pyarrow\__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\numpy\core\_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Sachini\anaconda3\Lib\asyncio\windows_events.py", line 322, in run_forever
#     super().run_forever()
#   File "C:\Users\Sachini\anaconda3\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "C:\Users\Sachini\anaconda3\Lib\asyncio\base_events.py", line 1986, in _run_once
#     handle._run()
#   File "C:\Users\Sachini\anaconda3\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Sachini\AppData\Local\Temp\ipykernel_14996\677827319.py", line 2, in <module>
#     import pandas as pd
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pandas\__init__.py", line 62, in <module>
#     from pandas.core.api import (
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pandas\core\api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pandas\core\arrays\arrow\__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pandas\core\arrays\arrow\array.py", line 50, in <module>
#     from pandas.core import (
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pandas\core\ops\__init__.py", line 8, in <module>
#     from pandas.core.ops.array_ops import (
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py", line 56, in <module>
#     from pandas.core.computation import expressions
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py", line 21, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pandas\core\computation\check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pandas\compat\_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "C:\Users\Sachini\anaconda3\Lib\importlib\__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\numexpr\__init__.py", line 24, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Sachini\anaconda3\Lib\asyncio\windows_events.py", line 322, in run_forever
#     super().run_forever()
#   File "C:\Users\Sachini\anaconda3\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "C:\Users\Sachini\anaconda3\Lib\asyncio\base_events.py", line 1986, in _run_once
#     handle._run()
#   File "C:\Users\Sachini\anaconda3\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Sachini\AppData\Local\Temp\ipykernel_14996\677827319.py", line 2, in <module>
#     import pandas as pd
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pandas\__init__.py", line 62, in <module>
#     from pandas.core.api import (
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pandas\core\api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pandas\core\arrays\arrow\__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pandas\core\arrays\arrow\array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py", line 60, in <module>
#     from pandas.core import (
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pandas\core\nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\pandas\compat\_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "C:\Users\Sachini\anaconda3\Lib\importlib\__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\bottleneck\__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\numpy\core\_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# Libraries loaded ✓

# %%
# load dataset
df = pd.read_csv("../data/processed_data/bank-additional-engineered.csv")
df.head(1)
# Out:
#          job  marital education housing loan month day_of_week  campaign  \
# 0  housemaid  married  basic.4y      no   no   may         mon         1
#
#    previous  cons.price.idx  cons.conf.idx   y  was_contacted_before  \
# 0         0          93.994          -36.4  no                     0
#
#    economic_index  is_risk  poutcome_success  is_cellular    age_group
# 0        0.979435        0                 0            0  working_age

# %%
df.shape
# Out:
# (41176, 18)

# %%
# Split features and target
X = df.drop(columns=['y'])
y = df['y'].map({'yes': 1, 'no': 0})

# %%
# Stratified Train-Test Split (Prevents data leakage during scaling/encoding)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41176 entries, 0 to 41175
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   job                   41176 non-null  object
#  1   marital               41176 non-null  object
#  2   education             41176 non-null  object
#  3   housing               41176 non-null  object
#  4   loan                  41176 non-null  object
#  5   month                 41176 non-null  object
#  6   day_of_week           41176 non-null  object
#  7   campaign              41176 non-null  int64
#  8   previous              41176 non-null  int64
#  9   cons.price.idx        41176 non-null  float64
#  10  cons.conf.idx         41176 non-null  float64
#  11  y                     41176 non-null  object
#  12  was_contacted_before  41176 non-null  int64
#  13  economic_index        41176 non-null  float64
#  14  is_risk               41176 non-null  int64
#  15  poutcome_success      41176 non-null  int64
#  16  is_cellular           41176 non-null  int64
#  17  age_group             41171 non-null  object
# dtypes: float64(3), int64(6), object(9)
# memory usage: 5.7+ MB

# %%
cat_cols = df.select_dtypes(include=['object','category']).columns.drop('y')

# %%
print(cat_cols)
# Out:
# Index(['job', 'marital', 'education', 'housing', 'loan', 'month',
#        'day_of_week', 'age_group'],
#       dtype='object')

# %%
num_cols = df.select_dtypes(include=['int64','float64']).columns

# %%
print(num_cols)
# Out:
# Index(['campaign', 'previous', 'cons.price.idx', 'cons.conf.idx',
#        'was_contacted_before', 'economic_index', 'is_risk', 'poutcome_success',
#        'is_cellular'],
#       dtype='object')

# %%
# Assemble Transformer Pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_cols),
        ('cat', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False), cat_cols)
    ],
    remainder='passthrough'  # Preserves engineered binary columns untouched
)

# %%
# Process Data matrices
X_train_proc = preprocessor.fit_transform(X_train)
X_test_proc = preprocessor.transform(X_test)

# %%
# Capture dynamic feature names for explainability (SHAP)
feature_names = preprocessor.get_feature_names_out()
X_train_df = pd.DataFrame(X_train_proc, columns=feature_names)
X_test_df = pd.DataFrame(X_test_proc, columns=feature_names)

# %%
# Feature Selection / Dimensionality Reduction
selector_rf = RandomForestClassifier(random_state=42, n_jobs=-1)
selector_rf.fit(X_train_proc, y_train)

# Calculate threshold boundaries (Keep features contributing above 0.5% total split variance)
importances = selector_rf.feature_importances_
important_indices = [i for i, imp in enumerate(importances) if imp > 0.005]

# Filter operational matrices
X_train_selected = X_train_proc[:, important_indices]
X_test_selected = X_test_proc[:, important_indices]
selected_feature_names = [feature_names[i] for i in important_indices]

print(f"Features retained: {len(selected_feature_names)} out of {len(feature_names)}")

for i, name in enumerate(selected_feature_names, 1):
    print(f"  {i}. {name}")

# Create a DataFrame of your features and their importances
feat_importances = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# Plotting the top features
plt.figure(figsize=(12, 8))
# Let's plot the top 20 features so the chart isn't overcrowded
sns.barplot(
    x='Importance', 
    y='Feature', 
    data=feat_importances.head(20), 
    palette='viridis',
    hue='Feature',
    legend=False
)
plt.title('Top 20 Feature Importances (Baseline Random Forest)', fontsize=14)
plt.xlabel('Importance Score')
plt.ylabel('Features')
plt.axvline(x=0.005, color='red', linestyle='--', label='Keep Threshold (0.5%)')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Features retained: 37 out of 45
#   1. num__campaign
#   2. num__previous
#   3. num__cons.price.idx
#   4. num__cons.conf.idx
#   5. num__was_contacted_before
#   6. num__economic_index
#   7. num__is_risk
#   8. num__poutcome_success
#   9. num__is_cellular
#   10. cat__job_blue-collar
#   11. cat__job_entrepreneur
#   12. cat__job_housemaid
#   13. cat__job_management
#   14. cat__job_retired
#   15. cat__job_self-employed
#   16. cat__job_services
#   17. cat__job_student
#   18. cat__job_technician
#   19. cat__job_unemployed
#   20. cat__marital_married
#   21. cat__marital_single
#   22. cat__education_basic.6y
#   23. cat__education_basic.9y
#   24. cat__education_high.school
#   25. cat__education_professional.course
#   26. cat__education_university.degree
#   27. cat__housing_yes
#   28. cat__loan_yes
#   29. cat__month_mar
#   30. cat__month_may
#   31. cat__month_oct
#   32. cat__day_of_week_mon
#   33. cat__day_of_week_thu
#   34. cat__day_of_week_tue
#   35. cat__day_of_week_wed
#   36. cat__age_group_senior/retired
#   37. cat__age_group_working_age

# %%
# Handle class Imbalance
smote = SMOTE(random_state=42)
X_train_balanced, y_train_balanced = smote.fit_resample(X_train_selected, y_train)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold

# %%
# Initialize Stratified 5-Fold Cross-Validation Strategy
cv_strategy = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
import sys

# Auto-detect if the notebook is running in Google Colab or locally
IN_COLAB = 'google.colab' in sys.modules
recommended_jobs = 1 if not IN_COLAB else -1

# %%
# Define Hyperparameter distribution grids for Optimization Search
models_config = {
    "Linear_Model_Logistic_Regression": {
        "model": LogisticRegression(max_iter=1000, random_state=42),
        "params": {"C": [0.01, 0.1, 1.0, 10.0], "penalty": ['l2']}
    },
    "Distance_Based_KNN": {
        "model": KNeighborsClassifier(),
        "params": {"n_neighbors": [3, 5, 11, 15], "weights": ['uniform', 'distance']}
    },
    "Tree_Based_Random_Forest": {
        "model": RandomForestClassifier(random_state=42),
        "params": {"n_estimators": [100, 200], "max_depth": [5, 10, 20], "min_samples_split": [2, 5]}
    },
    "Ensemble_Boosting_XGBoost": {
        "model": XGBClassifier(random_state=42, eval_metric='logloss'),
        "params": {"n_estimators": [100, 200], "learning_rate": [0.01, 0.1, 0.2], "max_depth": [3, 6, 9]}
    }
}

best_estimators = {}

# Execute Random Search Optimization Across Frameworks
for name, config in models_config.items():
    print(f"Optimizing Hyperparameters for: {name}...")
    search = RandomizedSearchCV(
        estimator=config["model"],
        param_distributions=config["params"],
        n_iter=5,
        cv=cv_strategy,
        scoring='f1',
        random_state=42,
        n_jobs=recommended_jobs  # This will dynamically switch!
    )
    search.fit(X_train_balanced, y_train_balanced)
    best_estimators[name] = search.best_estimator_
    print(f"Best Configuration: {search.best_params_}\n")
# Out:
# Optimizing Hyperparameters for: Linear_Model_Logistic_Regression...
# Best Configuration: {'penalty': 'l2', 'C': 10.0}
#
# Optimizing Hyperparameters for: Distance_Based_KNN...
# Best Configuration: {'weights': 'distance', 'n_neighbors': 3}
#
# Optimizing Hyperparameters for: Tree_Based_Random_Forest...
# Best Configuration: {'n_estimators': 200, 'min_samples_split': 2, 'max_depth': 20}
#
# Optimizing Hyperparameters for: Ensemble_Boosting_XGBoost...
# Best Configuration: {'n_estimators': 100, 'max_depth': 6, 'learning_rate': 0.1}

# %%
# Deep Learning Category (Artificial Neural Network - ANN)
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping

def build_ann(input_dim):
    model = Sequential([
        Input(shape=(input_dim,)),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dropout(0.2),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['AUC'])
    return model

# Initialize Deep Learning Architecture Instance
ann_model = build_ann(X_train_balanced.shape[1])
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

print("Training Artificial Neural Network Model Stack...")
ann_model.fit(
    X_train_balanced, y_train_balanced,
    epochs=20,
    batch_size=64,
    validation_split=0.1,
    callbacks=[early_stop],
    verbose=0
)
best_estimators["Deep_Learning_ANN"] = ann_model
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 # Deep Learning Category (Artificial Neural Network - ANN)
# ----> 2 import tensorflow as tf
#       3 from tensorflow.keras.models import Sequential
#       4 from tensorflow.keras.layers import Dense, Dropout, Input
#
# File ~\anaconda3\Lib\site-packages\tensorflow\__init__.py:49
#      46 from tensorflow.python import tf2 as _tf2
#      47 _tf2.enable()
# ---> 49 from tensorflow._api.v2 import __internal__
#      50 from tensorflow._api.v2 import __operators__
#      51 from tensorflow._api.v2 import audio
#
# File ~\anaconda3\Lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py:13
#      11 from tensorflow._api.v2.__internal__ import distribute
#      12 from tensorflow._api.v2.__internal__ import eager_context
# ---> 13 from tensorflow._api.v2.__internal__ import feature_column
#      14 from tensorflow._api.v2.__internal__ import function
#      15 from tensorflow._api.v2.__internal__ import graph_util
#
# File ~\anaconda3\Lib\site-packages\tensorflow\_api\v2\__internal__\feature_column\__init__.py:8
#       3 """Public API for tf._api.v2.__internal__.feature_column namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.feature_column.feature_column_v2 import DenseColumn # line: 1777
#       9 from tensorflow.python.feature_column.feature_column_v2 import FeatureTransformationCache # line: 1962
#      10 from tensorflow.python.feature_column.feature_column_v2 import SequenceDenseColumn # line: 1941
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\feature_column\feature_column_v2.py:38
#      36 from tensorflow.python.data.ops import readers
#      37 from tensorflow.python.eager import context
# ---> 38 from tensorflow.python.feature_column import feature_column as fc_old
#      39 from tensorflow.python.feature_column import feature_column_v2_types as fc_types
#      40 from tensorflow.python.feature_column import serialization
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\feature_column\feature_column.py:41
#      39 from tensorflow.python.framework import sparse_tensor as sparse_tensor_lib
#      40 from tensorflow.python.framework import tensor_shape
# ---> 41 from tensorflow.python.layers import base
#      42 from tensorflow.python.ops import array_ops
#      43 from tensorflow.python.ops import array_ops_stack
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\layers\base.py:16
#       1 # Copyright 2015 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # =============================================================================
#      15 """Contains the base Layer class, from which all layers inherit."""
# ---> 16 from tensorflow.python.keras.legacy_tf_layers import base
#      18 InputSpec = base.InputSpec
#      20 keras_style_scope = base.keras_style_scope
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\keras\__init__.py:25
#      22 from tensorflow.python.keras import distribute
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from tensorflow.python.keras import models
#      27 from tensorflow.python.keras.engine.input_layer import Input
#      28 from tensorflow.python.keras.engine.sequential import Sequential
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\keras\models.py:22
#      20 from tensorflow.python.keras import metrics as metrics_module
#      21 from tensorflow.python.keras import optimizer_v1
# ---> 22 from tensorflow.python.keras.engine import functional
#      23 from tensorflow.python.keras.engine import sequential
#      24 from tensorflow.python.keras.engine import training
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\keras\engine\functional.py:33
#      31 from tensorflow.python.keras.engine import input_spec
#      32 from tensorflow.python.keras.engine import node as node_module
# ---> 33 from tensorflow.python.keras.engine import training as training_lib
#      34 from tensorflow.python.keras.engine import training_utils
#      35 from tensorflow.python.keras.saving.saved_model import network_serialization
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\keras\engine\training.py:54
#      52 from tensorflow.python.keras.mixed_precision import loss_scale_optimizer as lso
#      53 from tensorflow.python.keras.mixed_precision import policy
# ---> 54 from tensorflow.python.keras.saving import hdf5_format
#      55 from tensorflow.python.keras.saving import save
#      56 from tensorflow.python.keras.saving import saving_utils
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\keras\saving\hdf5_format.py:40
#      36 try:
#      37   # Disable loading HDF5 plugins from a default path and prevent ZDI-CAN-25480.
#      38   # Importing h5py prior to importing tensorflow will restore the old behavior.
#      39   os.environ['HDF5_PLUGIN_PATH'] = 'disable'
# ---> 40   import h5py
#      41   HDF5_OBJECT_HEADER_LIMIT = 64512
#      42 except ImportError:
#
# File ~\anaconda3\Lib\site-packages\h5py\__init__.py:45
#      36     _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
#      37            "this may cause problems").format(
#      38             '{0}.{1}.{2}'.format(*version.hdf5_version_tuple),
#      39             '{0}.{1}.{2}'.format(*version.hdf5_built_version_tuple)
#      40     ))
#      43 _errors.silence_errors()
# ---> 45 from ._conv import register_converters as _register_converters, \
#      46                    unregister_converters as _unregister_converters
#      47 _register_converters()
#      48 atexit.register(_unregister_converters)
#
# File h5py\\_conv.pyx:1, in init h5py._conv()
#
# File h5py\\h5r.pyx:1, in init h5py.h5r()
#
# File h5py\\h5p.pyx:1, in init h5py.h5p()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, precision_recall_curve, auc, roc_curve


metrics_data = {}

ml_models = {
    "LogReg": best_estimators["Linear_Model_Logistic_Regression"],
    "KNN": best_estimators["Distance_Based_KNN"],
    "RF": best_estimators["Tree_Based_Random_Forest"],
    "XGBoost": best_estimators["Ensemble_Boosting_XGBoost"]
}

# Calculate metrics for the standard models
for name, model in ml_models.items():
    preds = model.predict(X_test_selected)
    metrics_data[name] = {
        "Accuracy": accuracy_score(y_test, preds),
        "Precision": precision_score(y_test, preds, zero_division=0),
        "Recall": recall_score(y_test, preds),
        "F1-Score": f1_score(y_test, preds),
        "ROC-AUC": roc_auc_score(y_test, preds_prob),
        "PR-AUC": pr_auc
    }

# Calculate metrics for the Keras ANN (ann_model)
ann_probs = ann_model.predict(X_test_selected).flatten()
ann_preds = (ann_probs >= 0.5).astype(int)
metrics_data["ANN"] = {
    "Accuracy": accuracy_score(y_test, ann_preds),
    "Precision": precision_score(y_test, ann_preds, zero_division=0),
    "Recall": recall_score(y_test, ann_preds),
    "F1-Score": f1_score(y_test, ann_preds)
}

results_df = pd.DataFrame(metrics_data).T
print(results_df.to_string())

# %%
# ROC curves, all models on one plot
plt.figure(figsize=(7,6))
for name, model, is_keras in [
    ("LogReg", best_estimators["Linear_Model_Logistic_Regression"], False), 
    ("KNN", best_estimators["Distance_Based_KNN"], False),
    ("RF", best_estimators["Tree_Based_Random_Forest"], False), 
    ("XGBoost", best_estimators["Ensemble_Boosting_XGBoost"], False), 
    ("ANN", ann_model, True)
]:
    probs = model.predict(X_test_selected).flatten() if is_keras else model.predict_proba(X_test_selected)[:,1]
    fpr, tpr, _ = roc_curve(y_test, probs)
    plt.plot(fpr, tpr, label=name)

plt.plot([0,1],[0,1],'k--', alpha=0.4)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curves — All Models")
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix

best_model = best_estimators["Ensemble_Boosting_XGBoost"]

# 2. Compute predictions and probabilities using the selected test features
preds = best_model.predict(X_test_selected)
probs = best_model.predict_proba(X_test_selected)[:, 1]

# 3. Generate and plot the Confusion Matrix
cm = confusion_matrix(y_test, preds)

plt.figure(figsize=(7, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens',
            xticklabels=['Predicted No', 'Predicted Yes'],
            yticklabels=['Actual No', 'Actual Yes'])
plt.title("Confusion Matrix — Best Model (XGBoost)")
plt.ylabel("Actual Label")
plt.xlabel("Predicted Label")
plt.show()

# 4. Look specifically at false negatives (Type II Errors)
fn_mask = (y_test == 1) & (preds == 0)
print(f"False negatives: {fn_mask.sum()} out of {(y_test==1).sum()} actual subscribers")

# %%
# Save the chosen model
import joblib

# Save the trained model
joblib.dump(best_model, "../models/term_deposit_model.pkl")

print("Model saved!")

# %%
import shap

# Extract the chosen baseline ensemble booster from our best models map
chosen_tree_model = best_estimators["Ensemble_Boosting_XGBoost"]

# Initialize TreeExplainer engine matrix
explainer = shap.TreeExplainer(chosen_tree_model)
shap_values = explainer(X_test_selected)

# Render Global Feature Contribution Summary Diagram
print("Generating SHAP summary profile data...")
shap.summary_plot(shap_values, X_test_selected, feature_names=selected_feature_names, show=False)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Sachini\anaconda3\Lib\asyncio\windows_events.py", line 322, in run_forever
#     super().run_forever()
#   File "C:\Users\Sachini\anaconda3\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "C:\Users\Sachini\anaconda3\Lib\asyncio\base_events.py", line 1986, in _run_once
#     handle._run()
#   File "C:\Users\Sachini\anaconda3\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Sachini\AppData\Local\Temp\ipykernel_14996\1663296209.py", line 1, in <module>
#     import shap
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\shap\__init__.py", line 3, in <module>
#     from ._explanation import Cohorts, Explanation
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\shap\_explanation.py", line 18, in <module>
#     from .utils._clustering import hclust_ordering
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\shap\utils\__init__.py", line 1, in <module>
#     from ._clustering import (
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\shap\utils\_clustering.py", line 13, in <module>
#     from numba import njit
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\numba\__init__.py", line 92, in <module>
#     from numba.core.decorators import (cfunc, jit, njit, stencil,
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\numba\core\decorators.py", line 12, in <module>
#     from numba.stencils.stencil import stencil
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\numba\stencils\stencil.py", line 11, in <module>
#     from numba.core import types, typing, utils, ir, config, ir_utils, registry
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\numba\core\ir_utils.py", line 14, in <module>
#     from numba.core.extending import _Intrinsic
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\numba\core\extending.py", line 19, in <module>
#     from numba.core.pythonapi import box, unbox, reflect, NativeValue  # noqa: F401
#   File "C:\Users\Sachini\anaconda3\Lib\site-packages\numba\core\pythonapi.py", line 11, in <module>
#     from numba import _helperlib
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\numpy\core\_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 import shap
#       3 # Extract the chosen baseline ensemble booster from our best models map
#       4 chosen_tree_model = best_estimators["Ensemble_Boosting_XGBoost"]
#
# File ~\anaconda3\Lib\site-packages\shap\__init__.py:3
#       1 from typing import Any, NoReturn
# ----> 3 from ._explanation import Cohorts, Explanation
#       5 # explainers
#       6 from .explainers import other
#
# File ~\anaconda3\Lib\site-packages\shap\_explanation.py:18
#      15 import sklearn
#      16 from slicer import Alias, Obj, Slicer
# ---> 18 from .utils._clustering import hclust_ordering
#      19 from .utils._exceptions import DimensionError
#      20 from .utils._general import OpChain
#
# File ~\anaconda3\Lib\site-packages\shap\utils\__init__.py:1
# ----> 1 from ._clustering import (
#       2     delta_minimization_order,
#       3     hclust,
#       4     hclust_ordering,
#       5     partition_tree,
#       6     partition_tree_shuffle,
#       7 )
#       8 from ._general import (
#       9     OpChain,
#      10     approximate_interactions,
#    (...)
#      20     suppress_stderr,
#      21 )
#      22 from ._masked_model import MaskedModel, make_masks
#
# File ~\anaconda3\Lib\site-packages\shap\utils\_clustering.py:13
#      11 import scipy.spatial
#      12 import sklearn
# ---> 13 from numba import njit
#      15 from ..utils._exceptions import DimensionError
#      16 from ._show_progress import show_progress
#
# File ~\anaconda3\Lib\site-packages\numba\__init__.py:92
#      89 from numba.core.types import *
#      91 # Re-export decorators
# ---> 92 from numba.core.decorators import (cfunc, jit, njit, stencil,
#      93                                    jit_module)
#      95 # Re-export vectorize decorators and the thread layer querying function
#      96 from numba.np.ufunc import (vectorize, guvectorize, threading_layer,
#      97                             get_num_threads, set_num_threads,
#      98                             set_parallel_chunksize, get_parallel_chunksize,
#      99                             get_thread_id)
#
# File ~\anaconda3\Lib\site-packages\numba\core\decorators.py:12
#       9 import logging
#      11 from numba.core.errors import DeprecationError, NumbaDeprecationWarning
# ---> 12 from numba.stencils.stencil import stencil
#      13 from numba.core import config, extending, sigutils, registry
#      15 _logger = logging.getLogger(__name__)
#
# File ~\anaconda3\Lib\site-packages\numba\stencils\stencil.py:11
#       8 import numpy as np
#       9 from llvmlite import ir as lir
# ---> 11 from numba.core import types, typing, utils, ir, config, ir_utils, registry
#      12 from numba.core.typing.templates import (CallableTemplate, signature,
#      13                                          infer_global, AbstractTemplate)
#      14 from numba.core.imputils import lower_builtin
#
# File ~\anaconda3\Lib\site-packages\numba\core\ir_utils.py:14
#      11 import warnings
#      13 import numba
# ---> 14 from numba.core.extending import _Intrinsic
#      15 from numba.core import types, typing, ir, analysis, postproc, rewrites, config
#      16 from numba.core.typing.templates import signature
#
# File ~\anaconda3\Lib\site-packages\numba\core\extending.py:19
#      17 from numba.core.datamodel import models   # noqa: F401
#      18 from numba.core.datamodel import register_default as register_model  # noqa: F401, E501
# ---> 19 from numba.core.pythonapi import box, unbox, reflect, NativeValue  # noqa: F401
#      20 from numba._helperlib import _import_cython_function  # noqa: F401
#      21 from numba.core.serialize import ReduceMixin
#
# File ~\anaconda3\Lib\site-packages\numba\core\pythonapi.py:11
#       8 from llvmlite.ir import Constant
#      10 import ctypes
# ---> 11 from numba import _helperlib
#      12 from numba.core import (
#      13     types, utils, config, lowering, cgutils, imputils, serialize,
#      14 )
#      15 from numba.core.utils import PYVERSION
#
# ImportError: numpy.core.multiarray failed to import
